# %%
import pymolviz as pmv
import numpy as np

# %%
pmv.util.colors.generate_shades("red", 10)
# Out:
# [(0.9090909090909091, 0.0, 0.0),
#  (0.8181818181818181, 0.0, 0.0),
#  (0.7272727272727273, 0.0, 0.0),
#  (0.6363636363636364, 0.0, 0.0),
#  (0.5454545454545454, 0.0, 0.0),
#  (0.4545454545454546, 0.0, 0.0),
#  (0.36363636363636365, 0.0, 0.0),
#  (0.2727272727272727, 0.0, 0.0),
#  (0.18181818181818177, 0.0, 0.0),
#  (0.09090909090909083, 0.0, 0.0)]
